# %% [markdown]
# # TensorFlow Classification

# %% [markdown]
# ## Data
#
# 1. Title: Pima Indians Diabetes Database
#
# 2. Sources:
#    (a) Original owners: National Institute of Diabetes and Digestive and
#                         Kidney Diseases
#                          Research Center, RMI Group Leader
#                           Applied Physics Laboratory
#                           The Johns Hopkins University
#                           Johns Hopkins Road
#                           Laurel, MD 20707
#                           (301) 953-6231
#    (c) Date received: 9 May 1990
#
# 3. Past Usage:
#     1. Smith,~J.~W., Everhart,~J.~E., Dickson,~W.~C., Knowler,~W.~C., \&
#        Johannes,~R.~S. (1988). Using the ADAP learning algorithm to forecast
#        the onset of diabetes mellitus.  In {\it Proceedings of the Symposium
#        on Computer Applications and Medical Care} (pp. 261--265).  IEEE
#        Computer Society Press.
#
#        The diagnostic, binary-valued variable investigated is whether the
#        patient shows signs of diabetes according to World Health Organization
#        criteria (i.e., if the 2 hour post-load plasma glucose was at least
#        200 mg/dl at any survey  examination or if found during routine medical
#        care).   The population lives near Phoenix, Arizona, USA.
#
#        Results: Their ADAP algorithm makes a real-valued prediction between
#        0 and 1.  This was transformed into a binary decision using a cutoff of
#        0.448.  Using 576 training instances, the sensitivity and specificity
#        of their algorithm was 76% on the remaining 192 instances.
#
# 4. Relevant Information:
#       Several constraints were placed on the selection of these instances from
#       a larger database.  In particular, all patients here are females at
#       least 21 years old of Pima Indian heritage.  ADAP is an adaptive learning
#       routine that generates and executes digital analogs of perceptron-like
#       devices.  It is a unique algorithm; see the paper for details.
#
# 5. Number of Instances: 768
#
# 6. Number of Attributes: 8 plus class
#
#     7. For Each Attribute: (all numeric-valued)
#        1. Number of times pregnant
#        2. Plasma glucose concentration a 2 hours in an oral glucose tolerance test
#        3. Diastolic blood pressure (mm Hg)
#        4. Triceps skin fold thickness (mm)
#        5. 2-Hour serum insulin (mu U/ml)
#        6. Body mass index (weight in kg/(height in m)^2)
#        7. Diabetes pedigree function
#        8. Age (years)
#        9. Class variable (0 or 1)
#
# 8. Missing Attribute Values: Yes
#
# 9. Class Distribution: (class value 1 is interpreted as "tested positive for
#    diabetes")
#
#    Class Value  Number of instances
#    0            500
#    1            268
#
# 10. Brief statistical analysis:
#
#         Attribute number:    Mean:   Standard Deviation:
#         1.                     3.8     3.4
#         2.                   120.9    32.0
#         3.                    69.1    19.4
#         4.                    20.5    16.0
#         5.                    79.8   115.2
#         6.                    32.0     7.9
#         7.                     0.5     0.3
#         8.                    33.2    11.8

# %%
import pandas as pd

# %%
diabetes = pd.read_csv('diabetes.csv')

# %%
diabetes.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diabetes.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %% [markdown]
# ### Clean the Data

# %%
cols_to_norm = ['Pregnancies', 'Glucose',
                'BloodPressure','SkinThickness',
                'Insulin', 'BMI', 
                'DiabetesPedigreeFunction']

# %%
diabetes[cols_to_norm] = diabetes[cols_to_norm].apply(
    lambda x: (x - x.min()) / (x.max() - x.min()))

# %%
diabetes.head()
# Out:
#    Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0     0.352941  0.743719       0.590164       0.353535  0.000000  0.500745
# 1     0.058824  0.427136       0.540984       0.292929  0.000000  0.396423
# 2     0.470588  0.919598       0.524590       0.000000  0.000000  0.347243
# 3     0.058824  0.447236       0.540984       0.232323  0.111111  0.418778
# 4     0.000000  0.688442       0.327869       0.353535  0.198582  0.642325
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                  0.234415   50        1
# 1                  0.116567   31        0
# 2                  0.253629   32        1
# 3                  0.038002   21        0
# 4                  0.943638   33        1

# %% [markdown]
# ### Feature Columns

# %%
diabetes.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
# Out:
# WARNING:tensorflow:From C:\Users\Farid\anaconda3-NEW\lib\site-packages\tensorflow\python\compat\v2_compat.py:101: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %% [markdown]
# ### Continuous Features
#
# * Number of times pregnant
# * Plasma glucose concentration a 2 hours in an oral glucose tolerance test
# * Diastolic blood pressure (mm Hg)
# * Triceps skin fold thickness (mm)
# * 2-Hour serum insulin (mu U/ml)
# * Body mass index (weight in kg/(height in m)^2)
# * Diabetes pedigree function

# %%
num_preg = tf.feature_column.numeric_column('Pregnancies')
plasma_gluc = tf.feature_column.numeric_column('Glucose')
dias_press = tf.feature_column.numeric_column('BloodPressure')
tricep = tf.feature_column.numeric_column('SkinThickness')
insulin = tf.feature_column.numeric_column('Insulin')
bmi = tf.feature_column.numeric_column('BMI')
diabetes_pedigree = tf.feature_column.numeric_column(
    'DiabetesPedigreeFunction')
age = tf.feature_column.numeric_column('Age')

# %% [markdown]
# ### Categorical Features

# %% [markdown]
# If you know the set of all possible feature values of a column and there are only a few of them, you can use categorical_column_with_vocabulary_list. If you don't know the set of possible values in advance you can use categorical_column_with_hash_bucket

# %%
assigned_group = tf.feature_column.categorical_column_with_vocabulary_list('Group',['A','B','C','D'])
# Alternative
# assigned_group = tf.feature_column.categorical_column_with_hash_bucket('Group', hash_bucket_size=10)

# %% [markdown]
# ### Converting Continuous to Categorical

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
diabetes['Age'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
age_buckets = tf.feature_column.bucketized_column(age, 
                          boundaries=[20,30,40,50,60,70,80])

# %% [markdown]
# ### Putting them together

# %%
feat_cols = [num_preg ,plasma_gluc,
             dias_press ,tricep ,
             insulin,bmi,diabetes_pedigree ,
             age_buckets]

# %% [markdown]
# ### Train Test Split

# %%
diabetes.head()
# Out:
#    Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0     0.352941  0.743719       0.590164       0.353535  0.000000  0.500745
# 1     0.058824  0.427136       0.540984       0.292929  0.000000  0.396423
# 2     0.470588  0.919598       0.524590       0.000000  0.000000  0.347243
# 3     0.058824  0.447236       0.540984       0.232323  0.111111  0.418778
# 4     0.000000  0.688442       0.327869       0.353535  0.198582  0.642325
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                  0.234415   50        1
# 1                  0.116567   31        0
# 2                  0.253629   32        1
# 3                  0.038002   21        0
# 4                  0.943638   33        1

# %%
diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    float64
#  1   Glucose                   768 non-null    float64
#  2   BloodPressure             768 non-null    float64
#  3   SkinThickness             768 non-null    float64
#  4   Insulin                   768 non-null    float64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(7), int64(2)
# memory usage: 54.1 KB

# %%
x_data = diabetes.drop('Outcome',axis=1)

# %%
labels = diabetes['Outcome']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x_data,
                                                    labels,
                                        test_size=0.33,
                                        random_state=101)

# %% [markdown]
# ### Input Function

# %%
input_func = tf.estimator.inputs.pandas_input_fn(
    x=X_train,
    y=y_train,
    batch_size=10,
    num_epochs=1000,
    shuffle=True)
# Out:
# WARNING:tensorflow:From C:\Users\Farid\anaconda3-NEW\lib\site-packages\tensorflow\python\util\lazy_loader.py:63: The name tf.estimator.inputs is deprecated. Please use tf.compat.v1.estimator.inputs instead.

# %% [markdown]
# ### Creating the Model

# %%
model = tf.estimator.LinearClassifier(
    feature_columns=feat_cols,
    n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\Farid\AppData\Local\Temp\tmpjtwt44gs
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\Farid\\AppData\\Local\\Temp\\tmpjtwt44gs', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
model.train(input_fn=input_func,steps=1000)
# Out:
# WARNING:tensorflow:From C:\Users\Farid\anaconda3-NEW\lib\site-packages\tensorflow\python\training\training_util.py:235: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# WARNING:tensorflow:From C:\Users\Farid\anaconda3-NEW\lib\site-packages\tensorflow_estimator\python\estimator\inputs\queues\feeding_queue_runner.py:60: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From C:\Users\Farid\anaconda3-NEW\lib\site-packages\tensorflow_estimator\python\estimator\inputs\queues\feeding_functions.py:491: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Calling model_fn.
# C:\Users\Farid\anaconda3-NEW\lib\site-packages\keras\engine\base_layer_v1.py:1684: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# WARNING:tensorflow:From C:\Users\Farid\anaconda3-NEW\lib\site-packages\tensorflow\python\training\monitored_session.py:907: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into C:\Users\Farid\AppData\Local\Temp\tmpjtwt44gs\model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# INFO:tensorflow:loss = 6.931472, step = 1
# INFO:tensorflow:global_step/sec: 251.078
# INFO:tensorflow:loss = 6.0888605, step = 101 (0.407 sec)
# INFO:tensorflow:global_step/sec: 375.67
# INFO:tensorflow:loss = 5.7890663, step = 201 (0.270 sec)
# INFO:tensorflow:global_step/sec: 353.107
# INFO:tensorflow:loss = 5.5342474, step = 301 (0.274 sec)
# INFO:tensorflow:global_step/sec: 394.975
# INFO:tensorflow:loss = 4.0365963, step = 401 (0.254 sec)
# INFO:tensorflow:global_step/sec: 341.055
# INFO:tensorflow:loss = 5.52779, step = 501 (0.293 sec)
# INFO:tensorflow:global_step/sec: 402.939
# INFO:tensorflow:loss = 5.8852053, step = 601 (0.251 sec)
# INFO:tensorflow:global_step/sec: 333.097
# INFO:tensorflow:loss = 3.4614217, step = 701 (0.303 sec)
# INFO:tensorflow:global_step/sec: 372.868
# INFO:tensorflow:loss = 7.5804725, step = 801 (0.262 sec)
# INFO:tensorflow:global_step/sec: 336.46
# INFO:tensorflow:loss = 5.6904826, step = 901 (0.297 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 1000...
# INFO:tensorflow:Saving checkpoints for 1000 into C:\Users\Farid\AppData\Local\Temp\tmpjtwt44gs\model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 1000...
# INFO:tensorflow:Loss for final step: 7.8171434.

# %% [markdown]
# ## Evaluation

# %%
eval_input_func = tf.estimator.inputs.pandas_input_fn(
      x=X_test,
      y=y_test,
      batch_size=10,
      num_epochs=1,
      shuffle=False)

# %%
results = model.evaluate(eval_input_func)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From C:\Users\Farid\anaconda3-NEW\lib\site-packages\tensorflow_estimator\python\estimator\canned\head.py:635: auc (from tensorflow.python.ops.metrics_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# The value of AUC returned by this may race with the update so this is deprecated. Please use tf.keras.metrics.AUC instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2021-11-17T20:48:34
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\Farid\AppData\Local\Temp\tmpjtwt44gs\model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 1.00682s
# INFO:tensorflow:Finished evaluation at 2021-11-17-20:48:35
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.72440946, accuracy_baseline = 0.65748036, auc = 0.78642714, auc_precision_recall = 0.63482296, average_loss = 0.5334681, global_step = 1000, label/mean = 0.34251967, loss = 5.211573, precision = 0.6, prediction/mean = 0.3778901, recall = 0.5862069
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: C:\Users\Farid\AppData\Local\Temp\tmpjtwt44gs\model.ckpt-1000

# %%
results
# Out:
# {'accuracy': 0.72440946,
#  'accuracy_baseline': 0.65748036,
#  'auc': 0.78642714,
#  'auc_precision_recall': 0.63482296,
#  'average_loss': 0.5334681,
#  'label/mean': 0.34251967,
#  'loss': 5.211573,
#  'precision': 0.6,
#  'prediction/mean': 0.3778901,
#  'recall': 0.5862069,
#  'global_step': 1000}

# %% [markdown]
# ## Predictions

# %%
pred_input_func = tf.estimator.inputs.pandas_input_fn(
      x=X_test,
      batch_size=10,
      num_epochs=1,
      shuffle=False)

# %%
# Predictions is a generator! 
predictions = model.predict(pred_input_func)

# %%
list(predictions)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\Farid\AppData\Local\Temp\tmpjtwt44gs\model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# [{'logits': array([0.14775252], dtype=float32),
#   'logistic': array([0.5368711], dtype=float32),
#   'probabilities': array([0.4631289, 0.5368711], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.59829366], dtype=float32),
#   'logistic': array([0.6452658], dtype=float32),
#   'probabilities': array([0.35473418, 0.6452658 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.31621146], dtype=float32),
#   'logistic': array([0.42159933], dtype=float32),
#   'probabilities': array([0.5784007 , 0.42159933], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.8045939], dtype=float32),
#   'logistic': array([0.3090437], dtype=float32),
#   'probabilities': array([0.6909563, 0.3090437], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8400285], dtype=float32),
#   'logistic': array([0.13704789], dtype=float32),
#   'probabilities': array([0.8629521 , 0.13704792], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.73487175], dtype=float32),
#   'logistic': array([0.6758734], dtype=float32),
#   'probabilities': array([0.32412657, 0.67587346], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.4838134], dtype=float32),
#   'logistic': array([0.61864793], dtype=float32),
#   'probabilities': array([0.38135207, 0.618648  ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.51905864], dtype=float32),
#   'logistic': array([0.3730724], dtype=float32),
#   'probabilities': array([0.6269277, 0.3730724], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1691049], dtype=float32),
#   'logistic': array([0.23701683], dtype=float32),
#   'probabilities': array([0.7629832 , 0.23701681], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1740062], dtype=float32),
#   'logistic': array([0.23613164], dtype=float32),
#   'probabilities': array([0.7638684, 0.2361316], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7617832], dtype=float32),
#   'logistic': array([0.14656717], dtype=float32),
#   'probabilities': array([0.85343283, 0.14656714], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7592309], dtype=float32),
#   'logistic': array([0.1468867], dtype=float32),
#   'probabilities': array([0.85311335, 0.1468867 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.7495144], dtype=float32),
#   'logistic': array([0.32092714], dtype=float32),
#   'probabilities': array([0.6790729 , 0.32092714], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.33687913], dtype=float32),
#   'logistic': array([0.5834322], dtype=float32),
#   'probabilities': array([0.41656777, 0.58343226], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.4506155], dtype=float32),
#   'logistic': array([0.18990684], dtype=float32),
#   'probabilities': array([0.81009316, 0.18990685], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.65227497], dtype=float32),
#   'logistic': array([0.34247708], dtype=float32),
#   'probabilities': array([0.6575229 , 0.34247705], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.48801398], dtype=float32),
#   'logistic': array([0.38036153], dtype=float32),
#   'probabilities': array([0.61963844, 0.3803615 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7897971], dtype=float32),
#   'logistic': array([0.14309761], dtype=float32),
#   'probabilities': array([0.85690236, 0.1430976 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.44477302], dtype=float32),
#   'logistic': array([0.39060426], dtype=float32),
#   'probabilities': array([0.60939574, 0.39060423], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8324131], dtype=float32),
#   'logistic': array([0.13795108], dtype=float32),
#   'probabilities': array([0.862049  , 0.13795106], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2821698], dtype=float32),
#   'logistic': array([0.21718109], dtype=float32),
#   'probabilities': array([0.78281885, 0.2171811 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.88371027], dtype=float32),
#   'logistic': array([0.29240954], dtype=float32),
#   'probabilities': array([0.70759046, 0.2924095 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.7065772], dtype=float32),
#   'logistic': array([0.6696444], dtype=float32),
#   'probabilities': array([0.3303556, 0.6696444], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3913875], dtype=float32),
#   'logistic': array([0.19918635], dtype=float32),
#   'probabilities': array([0.8008137 , 0.19918635], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.428398], dtype=float32),
#   'logistic': array([0.19334841], dtype=float32),
#   'probabilities': array([0.8066516 , 0.19334842], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.2509819], dtype=float32),
#   'logistic': array([0.77746975], dtype=float32),
#   'probabilities': array([0.2225302 , 0.77746975], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.4888418], dtype=float32),
#   'logistic': array([0.18409562], dtype=float32),
#   'probabilities': array([0.8159044 , 0.18409564], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.7380252], dtype=float32),
#   'logistic': array([0.32343614], dtype=float32),
#   'probabilities': array([0.67656386, 0.32343614], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.9980185], dtype=float32),
#   'logistic': array([0.11941111], dtype=float32),
#   'probabilities': array([0.8805889 , 0.11941112], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.3975339], dtype=float32),
#   'logistic': array([0.598095], dtype=float32),
#   'probabilities': array([0.40190497, 0.598095  ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([2.5881424], dtype=float32),
#   'logistic': array([0.9300946], dtype=float32),
#   'probabilities': array([0.06990547, 0.93009454], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.41442412], dtype=float32),
#   'logistic': array([0.3978518], dtype=float32),
#   'probabilities': array([0.60214823, 0.39785177], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.84471506], dtype=float32),
#   'logistic': array([0.30054268], dtype=float32),
#   'probabilities': array([0.69945735, 0.30054268], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.25071228], dtype=float32),
#   'logistic': array([0.5623518], dtype=float32),
#   'probabilities': array([0.4376482, 0.5623518], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.0475327], dtype=float32),
#   'logistic': array([0.25969917], dtype=float32),
#   'probabilities': array([0.74030083, 0.25969917], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.292956], dtype=float32),
#   'logistic': array([0.42728037], dtype=float32),
#   'probabilities': array([0.5727197 , 0.42728037], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.12337661], dtype=float32),
#   'logistic': array([0.5308051], dtype=float32),
#   'probabilities': array([0.46919492, 0.5308051 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.5280732], dtype=float32),
#   'logistic': array([0.62903357], dtype=float32),
#   'probabilities': array([0.3709664 , 0.62903357], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.2276963], dtype=float32),
#   'logistic': array([0.7734151], dtype=float32),
#   'probabilities': array([0.22658488, 0.7734151 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.68917483], dtype=float32),
#   'logistic': array([0.33421665], dtype=float32),
#   'probabilities': array([0.66578335, 0.33421662], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.4915789], dtype=float32),
#   'logistic': array([0.18368483], dtype=float32),
#   'probabilities': array([0.8163152 , 0.18368486], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.26341915], dtype=float32),
#   'logistic': array([0.5654766], dtype=float32),
#   'probabilities': array([0.43452337, 0.5654766 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6158856], dtype=float32),
#   'logistic': array([0.16577303], dtype=float32),
#   'probabilities': array([0.8342269 , 0.16577308], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.14781117], dtype=float32),
#   'logistic': array([0.5368857], dtype=float32),
#   'probabilities': array([0.46311438, 0.5368857 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.693371], dtype=float32),
#   'logistic': array([0.15533301], dtype=float32),
#   'probabilities': array([0.84466696, 0.15533301], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.020767], dtype=float32),
#   'logistic': array([0.11703968], dtype=float32),
#   'probabilities': array([0.88296026, 0.1170397 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.3491975], dtype=float32),
#   'logistic': array([0.5864229], dtype=float32),
#   'probabilities': array([0.41357705, 0.586423  ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5630558], dtype=float32),
#   'logistic': array([0.1732086], dtype=float32),
#   'probabilities': array([0.8267914 , 0.17320861], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2997605], dtype=float32),
#   'logistic': array([0.21420535], dtype=float32),
#   'probabilities': array([0.7857947 , 0.21420532], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7603331], dtype=float32),
#   'logistic': array([0.1467486], dtype=float32),
#   'probabilities': array([0.8532514 , 0.14674865], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6239145], dtype=float32),
#   'logistic': array([0.1646657], dtype=float32),
#   'probabilities': array([0.83533424, 0.16466571], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.0442766], dtype=float32),
#   'logistic': array([0.26032564], dtype=float32),
#   'probabilities': array([0.7396743 , 0.26032567], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1323067], dtype=float32),
#   'logistic': array([0.24373567], dtype=float32),
#   'probabilities': array([0.7562643 , 0.24373567], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.48062158], dtype=float32),
#   'logistic': array([0.38210538], dtype=float32),
#   'probabilities': array([0.61789465, 0.38210538], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.78773], dtype=float32),
#   'logistic': array([0.14335129], dtype=float32),
#   'probabilities': array([0.85664874, 0.14335127], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3220627], dtype=float32),
#   'logistic': array([0.2104753], dtype=float32),
#   'probabilities': array([0.7895247 , 0.21047531], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.4323988], dtype=float32),
#   'logistic': array([0.19272518], dtype=float32),
#   'probabilities': array([0.8072748, 0.1927252], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2785417], dtype=float32),
#   'logistic': array([0.21779856], dtype=float32),
#   'probabilities': array([0.7822014 , 0.21779856], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.08798754], dtype=float32),
#   'logistic': array([0.5219827], dtype=float32),
#   'probabilities': array([0.4780173, 0.5219827], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6829584], dtype=float32),
#   'logistic': array([0.1567041], dtype=float32),
#   'probabilities': array([0.8432959 , 0.15670413], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1945348], dtype=float32),
#   'logistic': array([0.2324489], dtype=float32),
#   'probabilities': array([0.7675511 , 0.23244889], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.58808386], dtype=float32),
#   'logistic': array([0.6429254], dtype=float32),
#   'probabilities': array([0.35707465, 0.6429254 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.62893426], dtype=float32),
#   'logistic': array([0.6522478], dtype=float32),
#   'probabilities': array([0.34775224, 0.6522478 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.21462297], dtype=float32),
#   'logistic': array([0.5534507], dtype=float32),
#   'probabilities': array([0.44654927, 0.5534507 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.6699909], dtype=float32),
#   'logistic': array([0.3384989], dtype=float32),
#   'probabilities': array([0.6615011, 0.3384989], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.01344717], dtype=float32),
#   'logistic': array([0.50336176], dtype=float32),
#   'probabilities': array([0.49663827, 0.50336176], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.413927], dtype=float32),
#   'logistic': array([0.19561538], dtype=float32),
#   'probabilities': array([0.8043845, 0.1956154], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3058535], dtype=float32),
#   'logistic': array([0.21318153], dtype=float32),
#   'probabilities': array([0.78681844, 0.21318153], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.671879], dtype=float32),
#   'logistic': array([0.1581738], dtype=float32),
#   'probabilities': array([0.8418262 , 0.15817381], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8217418], dtype=float32),
#   'logistic': array([0.139225], dtype=float32),
#   'probabilities': array([0.860775  , 0.13922499], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.51052964], dtype=float32),
#   'logistic': array([0.6249306], dtype=float32),
#   'probabilities': array([0.37506938, 0.6249306 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.0930612], dtype=float32),
#   'logistic': array([0.2510423], dtype=float32),
#   'probabilities': array([0.7489577 , 0.25104225], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.28891116], dtype=float32),
#   'logistic': array([0.42827046], dtype=float32),
#   'probabilities': array([0.57172954, 0.42827046], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.31348622], dtype=float32),
#   'logistic': array([0.57773596], dtype=float32),
#   'probabilities': array([0.422264  , 0.57773596], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.823137], dtype=float32),
#   'logistic': array([0.30509818], dtype=float32),
#   'probabilities': array([0.6949018 , 0.30509818], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.55730414], dtype=float32),
#   'logistic': array([0.6358285], dtype=float32),
#   'probabilities': array([0.36417148, 0.63582855], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.9609103], dtype=float32),
#   'logistic': array([0.12336853], dtype=float32),
#   'probabilities': array([0.87663144, 0.12336856], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.49773943], dtype=float32),
#   'logistic': array([0.6219279], dtype=float32),
#   'probabilities': array([0.37807208, 0.621928  ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8193922], dtype=float32),
#   'logistic': array([0.13950682], dtype=float32),
#   'probabilities': array([0.8604932 , 0.13950682], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.32987463], dtype=float32),
#   'logistic': array([0.5817289], dtype=float32),
#   'probabilities': array([0.41827112, 0.5817289 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.6561303], dtype=float32),
#   'logistic': array([0.34160942], dtype=float32),
#   'probabilities': array([0.6583905, 0.3416094], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5086985], dtype=float32),
#   'logistic': array([0.18113178], dtype=float32),
#   'probabilities': array([0.8188682 , 0.18113177], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.3516357], dtype=float32),
#   'logistic': array([0.58701414], dtype=float32),
#   'probabilities': array([0.41298586, 0.5870142 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.30595922], dtype=float32),
#   'logistic': array([0.57589865], dtype=float32),
#   'probabilities': array([0.42410135, 0.57589865], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.26759064], dtype=float32),
#   'logistic': array([0.5665013], dtype=float32),
#   'probabilities': array([0.43349868, 0.5665013 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.56966], dtype=float32),
#   'logistic': array([0.17226487], dtype=float32),
#   'probabilities': array([0.8277351 , 0.17226487], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.41066557], dtype=float32),
#   'logistic': array([0.39875257], dtype=float32),
#   'probabilities': array([0.60124743, 0.39875254], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.660147], dtype=float32),
#   'logistic': array([0.15974227], dtype=float32),
#   'probabilities': array([0.8402577 , 0.15974227], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.98457086], dtype=float32),
#   'logistic': array([0.72801423], dtype=float32),
#   'probabilities': array([0.27198577, 0.72801423], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.5065497], dtype=float32),
#   'logistic': array([0.81854934], dtype=float32),
#   'probabilities': array([0.1814507 , 0.81854934], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.45097446], dtype=float32),
#   'logistic': array([0.6108709], dtype=float32),
#   'probabilities': array([0.3891291, 0.6108709], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3913473], dtype=float32),
#   'logistic': array([0.19919276], dtype=float32),
#   'probabilities': array([0.80080724, 0.19919276], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.04799533], dtype=float32),
#   'logistic': array([0.48800346], dtype=float32),
#   'probabilities': array([0.5119965 , 0.48800343], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.5119851], dtype=float32),
#   'logistic': array([0.37472832], dtype=float32),
#   'probabilities': array([0.62527174, 0.37472832], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.0035876], dtype=float32),
#   'logistic': array([0.5008969], dtype=float32),
#   'probabilities': array([0.49910307, 0.5008969 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.47164375], dtype=float32),
#   'logistic': array([0.38422728], dtype=float32),
#   'probabilities': array([0.6157727 , 0.38422728], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.11052072], dtype=float32),
#   'logistic': array([0.47239792], dtype=float32),
#   'probabilities': array([0.5276021 , 0.47239792], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5758976], dtype=float32),
#   'logistic': array([0.17137727], dtype=float32),
#   'probabilities': array([0.82862276, 0.17137727], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.35591805], dtype=float32),
#   'logistic': array([0.5880519], dtype=float32),
#   'probabilities': array([0.41194803, 0.5880519 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.281731], dtype=float32),
#   'logistic': array([0.56997055], dtype=float32),
#   'probabilities': array([0.43002945, 0.56997055], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.243097], dtype=float32),
#   'logistic': array([0.2238974], dtype=float32),
#   'probabilities': array([0.77610266, 0.2238974 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.435612], dtype=float32),
#   'logistic': array([0.19222578], dtype=float32),
#   'probabilities': array([0.80777425, 0.1922258 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5579014], dtype=float32),
#   'logistic': array([0.17394799], dtype=float32),
#   'probabilities': array([0.826052  , 0.17394799], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.0570664], dtype=float32),
#   'logistic': array([0.25787047], dtype=float32),
#   'probabilities': array([0.74212956, 0.25787047], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.4003768], dtype=float32),
#   'logistic': array([0.4012218], dtype=float32),
#   'probabilities': array([0.5987782 , 0.40122184], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.724072], dtype=float32),
#   'logistic': array([0.1513474], dtype=float32),
#   'probabilities': array([0.84865254, 0.15134741], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.7560336], dtype=float32),
#   'logistic': array([0.31950805], dtype=float32),
#   'probabilities': array([0.6804919 , 0.31950802], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1267343], dtype=float32),
#   'logistic': array([0.24476427], dtype=float32),
#   'probabilities': array([0.75523573, 0.24476428], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.1220622], dtype=float32),
#   'logistic': array([0.10697091], dtype=float32),
#   'probabilities': array([0.8930291 , 0.10697091], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8089445], dtype=float32),
#   'logistic': array([0.1407657], dtype=float32),
#   'probabilities': array([0.8592343 , 0.14076576], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.958367], dtype=float32),
#   'logistic': array([0.7227947], dtype=float32),
#   'probabilities': array([0.27720526, 0.7227947 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.4937963], dtype=float32),
#   'logistic': array([0.18335265], dtype=float32),
#   'probabilities': array([0.8166474, 0.1833526], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7550602], dtype=float32),
#   'logistic': array([0.1474101], dtype=float32),
#   'probabilities': array([0.8525899, 0.1474101], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6593812], dtype=float32),
#   'logistic': array([0.15984508], dtype=float32),
#   'probabilities': array([0.8401549 , 0.15984508], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.02880824], dtype=float32),
#   'logistic': array([0.50720155], dtype=float32),
#   'probabilities': array([0.49279848, 0.5072016 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.1733005], dtype=float32),
#   'logistic': array([0.456783], dtype=float32),
#   'probabilities': array([0.543217  , 0.45678297], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1317021], dtype=float32),
#   'logistic': array([0.24384713], dtype=float32),
#   'probabilities': array([0.75615287, 0.24384712], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.28290492], dtype=float32),
#   'logistic': array([0.42974174], dtype=float32),
#   'probabilities': array([0.57025826, 0.42974174], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3819367], dtype=float32),
#   'logistic': array([0.20069814], dtype=float32),
#   'probabilities': array([0.79930186, 0.20069815], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3031898], dtype=float32),
#   'logistic': array([0.21362868], dtype=float32),
#   'probabilities': array([0.7863713 , 0.21362866], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.08265913], dtype=float32),
#   'logistic': array([0.479347], dtype=float32),
#   'probabilities': array([0.520653  , 0.47934696], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.0548898], dtype=float32),
#   'logistic': array([0.513719], dtype=float32),
#   'probabilities': array([0.486281, 0.513719], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7237204], dtype=float32),
#   'logistic': array([0.15139258], dtype=float32),
#   'probabilities': array([0.8486074 , 0.15139256], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.356054], dtype=float32),
#   'logistic': array([0.41191512], dtype=float32),
#   'probabilities': array([0.58808494, 0.41191512], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.7189307], dtype=float32),
#   'logistic': array([0.6723715], dtype=float32),
#   'probabilities': array([0.3276285, 0.6723715], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.2371118], dtype=float32),
#   'logistic': array([0.55900174], dtype=float32),
#   'probabilities': array([0.44099823, 0.5590018 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.30185902], dtype=float32),
#   'logistic': array([0.4251031], dtype=float32),
#   'probabilities': array([0.5748969 , 0.42510307], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.26386893], dtype=float32),
#   'logistic': array([0.5655871], dtype=float32),
#   'probabilities': array([0.43441287, 0.5655871 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1377448], dtype=float32),
#   'logistic': array([0.24273464], dtype=float32),
#   'probabilities': array([0.7572653 , 0.24273466], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3539602], dtype=float32),
#   'logistic': array([0.20522368], dtype=float32),
#   'probabilities': array([0.7947763, 0.2052237], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7502406], dtype=float32),
#   'logistic': array([0.14801681], dtype=float32),
#   'probabilities': array([0.85198313, 0.14801686], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.97230995], dtype=float32),
#   'logistic': array([0.27442032], dtype=float32),
#   'probabilities': array([0.7255797 , 0.27442032], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.06704128], dtype=float32),
#   'logistic': array([0.51675403], dtype=float32),
#   'probabilities': array([0.48324594, 0.51675403], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.74600375], dtype=float32),
#   'logistic': array([0.6783073], dtype=float32),
#   'probabilities': array([0.32169268, 0.6783073 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.130818], dtype=float32),
#   'logistic': array([0.24401018], dtype=float32),
#   'probabilities': array([0.7559898 , 0.24401015], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.550272], dtype=float32),
#   'logistic': array([0.17504701], dtype=float32),
#   'probabilities': array([0.824953, 0.175047], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.38913035], dtype=float32),
#   'logistic': array([0.40392667], dtype=float32),
#   'probabilities': array([0.5960733 , 0.40392667], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1884081], dtype=float32),
#   'logistic': array([0.23354372], dtype=float32),
#   'probabilities': array([0.7664563 , 0.23354377], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7125376], dtype=float32),
#   'logistic': array([0.15283486], dtype=float32),
#   'probabilities': array([0.8471651 , 0.15283486], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5369282], dtype=float32),
#   'logistic': array([0.17698225], dtype=float32),
#   'probabilities': array([0.8230177 , 0.17698227], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7996669], dtype=float32),
#   'logistic': array([0.14189163], dtype=float32),
#   'probabilities': array([0.85810834, 0.14189161], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.49320847], dtype=float32),
#   'logistic': array([0.37913805], dtype=float32),
#   'probabilities': array([0.62086195, 0.37913805], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.0864862], dtype=float32),
#   'logistic': array([0.74771947], dtype=float32),
#   'probabilities': array([0.2522805 , 0.74771947], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.2759632], dtype=float32),
# ...
#  {'logits': array([0.84347117], dtype=float32),
#   'logistic': array([0.69919574], dtype=float32),
#   'probabilities': array([0.3008042 , 0.69919574], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.5460272], dtype=float32),
#   'logistic': array([0.63321334], dtype=float32),
#   'probabilities': array([0.3667866 , 0.63321334], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.83995974], dtype=float32),
#   'logistic': array([0.69845676], dtype=float32),
#   'probabilities': array([0.3015433 , 0.69845676], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.2930256], dtype=float32),
#   'logistic': array([0.42726332], dtype=float32),
#   'probabilities': array([0.5727367, 0.4272633], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.71451217], dtype=float32),
#   'logistic': array([0.32860255], dtype=float32),
#   'probabilities': array([0.67139745, 0.3286026 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.15238369], dtype=float32),
#   'logistic': array([0.5380224], dtype=float32),
#   'probabilities': array([0.4619776 , 0.53802234], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.4356968], dtype=float32),
#   'logistic': array([0.19221258], dtype=float32),
#   'probabilities': array([0.8077874 , 0.19221261], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6042376], dtype=float32),
#   'logistic': array([0.1673902], dtype=float32),
#   'probabilities': array([0.83260983, 0.1673902 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.4721193], dtype=float32),
#   'logistic': array([0.18662068], dtype=float32),
#   'probabilities': array([0.81337935, 0.18662071], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.02629197], dtype=float32),
#   'logistic': array([0.5065726], dtype=float32),
#   'probabilities': array([0.49342737, 0.5065726 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.6466875], dtype=float32),
#   'logistic': array([0.06619349], dtype=float32),
#   'probabilities': array([0.93380654, 0.06619347], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.94702744], dtype=float32),
#   'logistic': array([0.27948302], dtype=float32),
#   'probabilities': array([0.720517  , 0.27948302], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6459048], dtype=float32),
#   'logistic': array([0.16166317], dtype=float32),
#   'probabilities': array([0.8383368, 0.1616632], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.99700236], dtype=float32),
#   'logistic': array([0.2695312], dtype=float32),
#   'probabilities': array([0.7304688, 0.2695312], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.0797657], dtype=float32),
#   'logistic': array([0.25355038], dtype=float32),
#   'probabilities': array([0.74644965, 0.25355035], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.8888675], dtype=float32),
#   'logistic': array([0.29134363], dtype=float32),
#   'probabilities': array([0.7086564 , 0.29134357], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.3194638], dtype=float32),
#   'logistic': array([0.7890925], dtype=float32),
#   'probabilities': array([0.21090749, 0.7890925 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.4386607], dtype=float32),
#   'logistic': array([0.19175282], dtype=float32),
#   'probabilities': array([0.80824715, 0.19175282], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8154826], dtype=float32),
#   'logistic': array([0.1399768], dtype=float32),
#   'probabilities': array([0.8600232, 0.1399768], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.3991722], dtype=float32),
#   'logistic': array([0.59848875], dtype=float32),
#   'probabilities': array([0.40151125, 0.59848875], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.15751183], dtype=float32),
#   'logistic': array([0.46070325], dtype=float32),
#   'probabilities': array([0.53929675, 0.46070325], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.7072002], dtype=float32),
#   'logistic': array([0.84647286], dtype=float32),
#   'probabilities': array([0.15352723, 0.8464728 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.50252545], dtype=float32),
#   'logistic': array([0.6230526], dtype=float32),
#   'probabilities': array([0.3769474 , 0.62305266], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8087437], dtype=float32),
#   'logistic': array([0.14079005], dtype=float32),
#   'probabilities': array([0.85921   , 0.14079003], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.5204468], dtype=float32),
#   'logistic': array([0.6272522], dtype=float32),
#   'probabilities': array([0.37274775, 0.6272522 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.20271409], dtype=float32),
#   'logistic': array([0.5505057], dtype=float32),
#   'probabilities': array([0.4494943, 0.5505057], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.1664597], dtype=float32),
#   'logistic': array([0.76250446], dtype=float32),
#   'probabilities': array([0.23749551, 0.7625045 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1167933], dtype=float32),
#   'logistic': array([0.24660662], dtype=float32),
#   'probabilities': array([0.7533934 , 0.24660657], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.4818664], dtype=float32),
#   'logistic': array([0.18514568], dtype=float32),
#   'probabilities': array([0.8148543 , 0.18514569], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.21766925], dtype=float32),
#   'logistic': array([0.55420345], dtype=float32),
#   'probabilities': array([0.44579655, 0.5542035 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6865875], dtype=float32),
#   'logistic': array([0.15622512], dtype=float32),
#   'probabilities': array([0.84377486, 0.15622514], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.3107201], dtype=float32),
#   'logistic': array([0.78763366], dtype=float32),
#   'probabilities': array([0.21236637, 0.7876336 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.02106678], dtype=float32),
#   'logistic': array([0.5052665], dtype=float32),
#   'probabilities': array([0.49473348, 0.5052665 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.478754], dtype=float32),
#   'logistic': array([0.18561569], dtype=float32),
#   'probabilities': array([0.81438434, 0.18561569], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.36382163], dtype=float32),
#   'logistic': array([0.5899652], dtype=float32),
#   'probabilities': array([0.41003475, 0.5899652 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.02007723], dtype=float32),
#   'logistic': array([0.49498087], dtype=float32),
#   'probabilities': array([0.5050191 , 0.49498084], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.0833867], dtype=float32),
#   'logistic': array([0.11072204], dtype=float32),
#   'probabilities': array([0.889278  , 0.11072207], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.0899657], dtype=float32),
#   'logistic': array([0.52247626], dtype=float32),
#   'probabilities': array([0.4775237 , 0.52247626], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.4719056], dtype=float32),
#   'logistic': array([0.61583465], dtype=float32),
#   'probabilities': array([0.3841653 , 0.61583465], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.1454219], dtype=float32),
#   'logistic': array([0.7586737], dtype=float32),
#   'probabilities': array([0.24132627, 0.75867367], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.434318], dtype=float32),
#   'logistic': array([0.8075732], dtype=float32),
#   'probabilities': array([0.1924268 , 0.80757326], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.34682685], dtype=float32),
#   'logistic': array([0.41415212], dtype=float32),
#   'probabilities': array([0.58584785, 0.41415212], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6208946], dtype=float32),
#   'logistic': array([0.16508153], dtype=float32),
#   'probabilities': array([0.8349185 , 0.16508155], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.2768536], dtype=float32),
#   'logistic': array([0.09305817], dtype=float32),
#   'probabilities': array([0.90694183, 0.09305817], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.9621458], dtype=float32),
#   'logistic': array([0.12323499], dtype=float32),
#   'probabilities': array([0.876765  , 0.12323501], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.11617], dtype=float32),
#   'logistic': array([0.2467224], dtype=float32),
#   'probabilities': array([0.7532776 , 0.24672239], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.6681691], dtype=float32),
#   'logistic': array([0.33890694], dtype=float32),
#   'probabilities': array([0.66109306, 0.3389069 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.9288571], dtype=float32),
#   'logistic': array([0.28315663], dtype=float32),
#   'probabilities': array([0.71684337, 0.28315663], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)}]

# %% [markdown]
# # DNN Classifier

# %%
dnn_model = tf.estimator.DNNClassifier(
    hidden_units=[10,10,10],
    feature_columns=feat_cols,
    n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\Farid\AppData\Local\Temp\tmpdlm9qzpr
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\Farid\\AppData\\Local\\Temp\\tmpdlm9qzpr', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
# UH OH! AN ERROR. Check out the video to see why and how to fix.
# https://github.com/tensorflow/tensorflow/blob/master/tensorflow/python/feature_column/feature_column.py
dnn_model.train(input_fn=input_func,steps=1000)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From C:\Users\Farid\anaconda3-NEW\lib\site-packages\tensorflow\python\training\adagrad.py:76: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into C:\Users\Farid\AppData\Local\Temp\tmpdlm9qzpr\model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# INFO:tensorflow:loss = 6.5340343, step = 1
# INFO:tensorflow:global_step/sec: 283.901
# INFO:tensorflow:loss = 7.654916, step = 101 (0.354 sec)
# INFO:tensorflow:global_step/sec: 378.518
# INFO:tensorflow:loss = 4.4502077, step = 201 (0.269 sec)
# INFO:tensorflow:global_step/sec: 356.887
# INFO:tensorflow:loss = 3.1934924, step = 301 (0.278 sec)
# INFO:tensorflow:global_step/sec: 388.828
# INFO:tensorflow:loss = 3.4172778, step = 401 (0.261 sec)
# INFO:tensorflow:global_step/sec: 384.344
# INFO:tensorflow:loss = 6.271475, step = 501 (0.257 sec)
# INFO:tensorflow:global_step/sec: 355.618
# INFO:tensorflow:loss = 3.426174, step = 601 (0.287 sec)
# INFO:tensorflow:global_step/sec: 327.637
# INFO:tensorflow:loss = 4.4670544, step = 701 (0.304 sec)
# INFO:tensorflow:global_step/sec: 362.061
# INFO:tensorflow:loss = 3.7101746, step = 801 (0.273 sec)
# INFO:tensorflow:global_step/sec: 356.887
# INFO:tensorflow:loss = 3.4652295, step = 901 (0.279 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 1000...
# INFO:tensorflow:Saving checkpoints for 1000 into C:\Users\Farid\AppData\Local\Temp\tmpdlm9qzpr\model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 1000...
# INFO:tensorflow:Loss for final step: 4.391493.

# %%
feat_cols = [num_preg ,plasma_gluc,dias_press ,
             tricep ,insulin,bmi,diabetes_pedigree ,
             age_buckets]

# %%
input_func = tf.estimator.inputs.pandas_input_fn(x=X_train,
                                                 y=y_train,
                                                 batch_size=10,
                                                 num_epochs=1000,
                                                 shuffle=True)

# %%
dnn_model = tf.estimator.DNNClassifier(hidden_units=[10,10,10],
                                       feature_columns=feat_cols,
                                       n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\Farid\AppData\Local\Temp\tmpapo9rp6j
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\Farid\\AppData\\Local\\Temp\\tmpapo9rp6j', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
dnn_model.train(input_fn=input_func,steps=1000)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into C:\Users\Farid\AppData\Local\Temp\tmpapo9rp6j\model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# INFO:tensorflow:loss = 7.525898, step = 1
# INFO:tensorflow:global_step/sec: 287.152
# INFO:tensorflow:loss = 4.291233, step = 101 (0.353 sec)
# INFO:tensorflow:global_step/sec: 374.265
# INFO:tensorflow:loss = 3.9347677, step = 201 (0.273 sec)
# INFO:tensorflow:global_step/sec: 331.991
# INFO:tensorflow:loss = 4.280212, step = 301 (0.294 sec)
# INFO:tensorflow:global_step/sec: 351.862
# INFO:tensorflow:loss = 3.2758534, step = 401 (0.290 sec)
# INFO:tensorflow:global_step/sec: 402.94
# INFO:tensorflow:loss = 6.465871, step = 501 (0.254 sec)
# INFO:tensorflow:global_step/sec: 384.342
# INFO:tensorflow:loss = 5.6498775, step = 601 (0.255 sec)
# INFO:tensorflow:global_step/sec: 348.184
# INFO:tensorflow:loss = 3.6018991, step = 701 (0.284 sec)
# INFO:tensorflow:global_step/sec: 275.655
# INFO:tensorflow:loss = 5.947736, step = 801 (0.359 sec)
# INFO:tensorflow:global_step/sec: 396.545
# INFO:tensorflow:loss = 3.0211463, step = 901 (0.256 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 1000...
# INFO:tensorflow:Saving checkpoints for 1000 into C:\Users\Farid\AppData\Local\Temp\tmpapo9rp6j\model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 1000...
# INFO:tensorflow:Loss for final step: 6.3911743.

# %%
eval_input_func = tf.estimator.inputs.pandas_input_fn(
      x=X_test,
      y=y_test,
      batch_size=10,
      num_epochs=1,
      shuffle=False)

# %%
dnn_model.evaluate(eval_input_func)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2021-11-17T20:53:55
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\Farid\AppData\Local\Temp\tmpapo9rp6j\model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.68549s
# INFO:tensorflow:Finished evaluation at 2021-11-17-20:53:56
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.7480315, accuracy_baseline = 0.65748036, auc = 0.82947904, auc_precision_recall = 0.7146437, average_loss = 0.47927797, global_step = 1000, label/mean = 0.34251967, loss = 4.682177, precision = 0.64935064, prediction/mean = 0.33581316, recall = 0.57471263
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: C:\Users\Farid\AppData\Local\Temp\tmpapo9rp6j\model.ckpt-1000
# {'accuracy': 0.7480315,
#  'accuracy_baseline': 0.65748036,
#  'auc': 0.82947904,
#  'auc_precision_recall': 0.7146437,
#  'average_loss': 0.47927797,
#  'label/mean': 0.34251967,
#  'loss': 4.682177,
#  'precision': 0.64935064,
#  'prediction/mean': 0.33581316,
#  'recall': 0.57471263,
#  'global_step': 1000}
